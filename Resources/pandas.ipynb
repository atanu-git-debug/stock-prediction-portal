# %%
import pandas as pd

# %%
df = pd.read_csv('call_activity.csv')
print(df)
# Out:
#     State  Account length  Area code International plan Voice mail plan  \
# 0      WV             141        408                 No              No
# 1      CA              13        408                 No             Yes
# 2      NJ              36        408                Yes             Yes
# 3      NV               4        510                 No              No
# 4      NJ             175        510                 No             Yes
# ..    ...             ...        ...                ...             ...
# 495    KS             118        408                Yes             Yes
# 496    CT               6        415                 No              No
# 497    NY             247        510                Yes             Yes
# 498    FL             114        408                 No              No
# 499    NV             159        415                 No              No
#
#      Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
type(df)
# Out:
# pandas.DataFrame

# %%
df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    WV             141        408                 No              No
# 1    CA              13        408                 No             Yes
# 2    NJ              36        408                Yes             Yes
# 3    NV               4        510                 No              No
# 4    NJ             175        510                 No             Yes
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     42              248.8               98
# 1                     25              235.2              104
# 2                     14              167.5               79
# 3                     45              161.9               85
# 4                     20              332.1              116
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             42.30              267.0               93             22.70
# ...

# %%
df.tail()
# Out:
#     State  Account length  Area code International plan Voice mail plan  \
# 495    KS             118        408                Yes             Yes
# 496    CT               6        415                 No              No
# 497    NY             247        510                Yes             Yes
# 498    FL             114        408                 No              No
# 499    NV             159        415                 No              No
#
#      Number vmail messages  Total day minutes  Total day calls  \
# 495                      2              295.0              144
# 496                      4              221.3               67
# 497                     41              102.7              145
# 498                     23              244.2               61
# 499                     11              186.8               96
#
#      Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   State                  500 non-null    str
#  1   Account length         500 non-null    int64
#  2   Area code              500 non-null    int64
#  3   International plan     500 non-null    str
#  4   Voice mail plan        500 non-null    str
#  5   Number vmail messages  500 non-null    int64
#  6   Total day minutes      500 non-null    float64
#  7   Total day calls        500 non-null    int64
#  8   Total day charge       500 non-null    float64
#  9   Total eve minutes      500 non-null    float64
#  10  Total eve calls        500 non-null    int64
#  11  Total eve charge       500 non-null    float64
#  12  Total night minutes    500 non-null    float64
#  13  Total night calls      500 non-null    int64
#  14  Total night charge     500 non-null    float64
# ...

# %%
df['Total intl charge']
# Out:
# 0      0.76
# 1      3.62
# 2      4.10
# 3      4.73
# 4      0.59
#        ...
# 495    1.16
# 496    5.08
# 497    0.38
# 498    4.32
# 499    0.59
# Name: Total intl charge, Length: 500, dtype: float64

# %%
type(df['Total intl charge'])
# Out:
# pandas.Series

# %% [markdown]
# ## Create a DataFrame from a dict

# %%
tempdict = {
    'Name' : ['Atanu','Lewis','Max','Landow'],
    'Degignation' : ['Viewer','Driver','Driver','Driver'],
    'Salary':[00000,100000000,10000000,10000000]
}

# %%
pd.DataFrame(tempdict)
# Out:
#      Name Degignation     Salary
# 0   Atanu      Viewer          0
# 1   Lewis      Driver  100000000
# 2     Max      Driver   10000000
# 3  Landow      Driver   10000000

# %%
df.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge'],
#       dtype='str')

# %%
df.dtypes
# Out:
# State                        str
# Account length             int64
# Area code                  int64
# International plan           str
# Voice mail plan              str
# Number vmail messages      int64
# Total day minutes        float64
# Total day calls            int64
# Total day charge         float64
# Total eve minutes        float64
# Total eve calls            int64
# Total eve charge         float64
# Total night minutes      float64
# Total night calls          int64
# Total night charge       float64
# Total intl minutes       float64
# Total intl calls           int64
# Total intl charge        float64
# dtype: object

# %%
df.State
# Out:
# 0      WV
# 1      CA
# 2      NJ
# 3      NV
# 4      NJ
#        ..
# 495    KS
# 496    CT
# 497    NY
# 498    FL
# 499    NV
# Name: State, Length: 500, dtype: str
